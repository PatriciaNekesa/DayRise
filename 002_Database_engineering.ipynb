# %%
import pandas as pd
import uuid
from sqlalchemy import create_engine, Column, Integer, String, ForeignKey, Text
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker, relationship
from bs4 import BeautifulSoup
import requests

# %%
# Setup session
Session = sessionmaker(bind=engine)
session = Session()

# %%
engine = create_engine('sqlite:///company_data.db')

Base = declarative_base()

# %%
# Define DataSource model
class DataSource(Base):
    __tablename__ = 'datasources'
    id = Column(String, primary_key=True, default=lambda: str(uuid.uuid4()))
    name = Column(String, nullable=False)
    url = Column(String, unique=True, nullable=False)

# WebsiteData Table
class WebsiteData(Base):
    __tablename__ = 'website_data'
    id = Column(Integer, primary_key=True, autoincrement=True)
    source_id = Column(String, ForeignKey('datasources.id'), nullable=False)
    data = Column(Text, nullable=True)  # Store scraped data

    # Relationship with DataSource
    source = relationship("DataSource", back_populates="data_entries")

# Link relationship in DataSource for querying related data
DataSource.data_entries = relationship("WebsiteData", back_populates="source")

# Create the table
Base.metadata.create_all(engine)

# %%
# Load Excel data
data_path = 'Dayrize_Automation_Database Screening+Patricia.xlsx'
url_column = 'Website URL '
name_column = 'Website Name'# Replace with the actual name of the column that contains URLs in your file
add_urls_from_excel(file_path=data_path, url_column=url_column, name_column=name_column)
# Out:
# URL already exists: https://www.bettershoes.org/home/material-selection
# URL already exists: https://hpp.arkema.com/en/materials-database/products
# URL already exists: https://quantis.com/who-we-guide/our-impact/sustainability-initiatives/waldb/
# URL already exists: https://envioes.com/en/product-sizes
# URL already exists: https://www.shipbob.com/blog/dimensional-weight-explained/
# URL already exists: http://www.fedex.com/in/tools/dimweight.html
# URL already exists: https://www.biobasedconsultancy.com/en/database
# URL already exists: https://textileexchange.org/find-certified-company/
# URL already exists: https://apparelcoalition.org/higg-product-tools/
# URL already exists: https://libguides.hb.se/c.php?g=676473&p=4818943
# URL already exists: https://login.lib.costello.pub.hb.se/login?qurl=https%3a%2f%2fwww.materialconnexion.online%2fdatabase
# URL already exists: https://www.stylepark.com/en/products/fabrics-textiles
# URL already exists: https://materialdistrict.com/material/
# URL already exists: https://ep.liu.se/databaser.aspx
# URL already exists: https://subjects.library.manchester.ac.uk/textiles/databases/
# URL already exists: https://libguides.library.kent.edu/c.php?g=278144&p=1853934
# URL already exists: http://www.fabricmarketing.com/#search
# URL already exists: https://elemental.green/10-trustworthy-green-product-databases-for-building-or-renovating-your-home/
# URL already exists: https://c2ccertified.org/certified-products
# URL already exists: https://transparencycatalog.com/
# URL already exists: https://hpdrepository.hpd-collaborative.org/Pages/Results.aspx
# URL already exists: https://declare.living-future.org/
# URL already exists: https://portal.mindfulmaterials.com/
# URL already exists: https://spot.ul.com/main-app/products/catalog/
# URL already exists: https://certified.greenseal.org/directory
# URL already exists: https://www.energystar.gov/products
# URL already exists: https://www.greenpointrated.com/
# URL already exists: https://healthymaterialslab.org/material-collections/product-libraries/external-certification-libraries
# URL already exists: https://www.resetbuild.com/
# URL already exists: https://www.environdec.com/library
# URL already exists: https://level.bifma.org/
# URL already exists: http://www.decorativesurfaces.org/cpa-green/naf-nauf-ulef.html
# URL already exists: https://ww2.arb.ca.gov/sites/default/files/classic/toxics/compwood/naf_ulef/listofnaf_ulef.htm
# URL already exists: https://buildingclean.ecomedes.com/
# URL already exists: https://www.oeko-tex.com/en/buying-guide
# URL already exists: https://www.epa.gov/saferchoice/products
# URL already exists: https://app.powerbi.com/view?r=eyJrIjoiMzAyMzVkNWMtNmJhOS00ZDg4LWIzMTItNzczMDkwODBiNjRmIiwidCI6ImIyNGM4YjA2LTUyMmMtNDZmZS05MDgwLTcwOTI2ZjhkZGRiMSIsImMiOjh9
# URL already exists: http://www.sustainableminds.com/transparency-products
# URL already exists: https://origin.build/#/materials?p=P&locale=en
# URL already exists: http://ecoscorecard.com/
# URL already exists: https://www.designerpages.com/search/?
# URL already exists: https://healthyurbanplaces.wixsite.com/materialspetal
# URL already exists: https://living-future.org/wp-content/uploads/2016/11/Materials-List.pdf
# URL already exists: https://s3.amazonaws.com/healthy-materials-lab/resources/Bullitt-Center-As-Built-Product-List-Jan-20141.pdf
# URL already exists: https://www.ewg.org/guides/cleaners/#.WrGPOJMbNE4
# URL already exists: https://www.svanen.se/en/
# URL already exists: https://ceh.org/wp-content/uploads/Purchaser-Guide-August-2017-2.pdf
# URL already exists: https://www.wood-database.com/wood-articles/restricted-and-endangered-wood-species/
# URL already exists: https://woodforgood.com/lifecycle-database/
# URL already exists: https://resourcefurniture.com/
# URL already exists: https://www.theconsumergoodsforum.com/
# URL already exists: https://www.iopp.org/i4a/pages/index.cfm?pageid=1
# URL already exists: https://www.iom3.org/group/packaging-group.html
# URL already exists: https://sustainablepackaging.org/our-work/public-resources/
# URL already exists: https://incpen.org/library/factsheets/
# URL already exists: https://www.luxepack.com/
# URL already exists: https://www.thepackagingconference.com/
# URL already exists: https://www.sustainability-in-packaging.com/home
# URL already exists: https://www.imengineeringwest.com/en/home.html
# URL already exists: https://www.packagingdigest.com/trends-issues/sustainability
# URL already exists: https://www.packagingstrategies.com/topics/2671-materials
# URL already exists: https://www.packworld.com/downloads
# URL already exists: https://astrx.org/resources/
# URL already exists: https://earthshiftglobal.com/packagesmart
# URL already exists: https://sphera.com/sustainable-packaging-calculator/
# URL already exists: https://sustainablepackaging.org/our-work/public-resources/
# URL already exists: https://www.billerud.com/managed-packaging/knowledge-center/case-studies/sustainable-materials-better-bottom-line2
# URL already exists: https://www.billerud.com/managed-packaging/knowledge-center/case-studies/the-outside-does-actually-matter
# URL already exists: https://www.billerud.com/managed-packaging/knowledge-center/case-studies/experience-the-joy-of-improvement
# URL already exists: https://www.billerud.com/managed-packaging/knowledge-center/case-studies/on-the-move-with-quality-and-style
# URL already exists: https://www.billerud.com/managed-packaging/knowledge-center/case-studies/a-great-fit-for-every-shoe
# URL already exists: https://www.theconsumergoodsforum.com/wp-content/uploads/2017/11/Global-Protocol-on-Packaging.pdf
# URL already exists: https://ilostat.ilo.org/data/
# URL already exists: https://www.oecd.org/employment/labour-stats/onlineoecdemploymentdatabase.htm
# URL already exists: https://data.unicef.org/topic/child-protection/child-labour/
# URL already exists: https://ourworldindata.org/child-labor
# URL already exists: https://jww.org/uyghur-china-forced-labor-database/
# URL already exists: https://www.dol.gov/agencies/ilab/reports/child-labor/list-of-goods
# URL already exists: https://resourcewatch.org/data/explore
# URL already exists: https://resourcewatch.org/data/explore
# URL already exists: https://resourcewatch.org/data/explore
# URL already exists: https://resourcewatch.org/data/explore
# URL already exists: https://resourcewatch.org/data/explore
# URL already exists: https://resourcewatch.org/data/explore
# URL already exists: https://www.suslab.ch/_files/ugd/d5df01_641484631fd44be1ab23dbd6294c9256.pdf
# URL already exists: http://lcdn.thinkstep.com/Node/
# URL already exists: https://www.gs1.org/voc/PackagingMaterialTypeCode
# URL already exists: https://www.gs1.org/voc/PackagingRecyclingProcessTypeCode
# URL already exists: https://www.gs1.org/voc/PackagingFunctionCode
# URL already exists: https://www.gs1.org/voc/PackagingFeatureCode
# URL already exists: https://www.gs1.org/voc/PackagingShapeCode
# URL already exists: https://www.materials.zone/platform
# URL already exists: https://guides.lib.udel.edu/fashion/databases
# URL already exists: https://guides.lib.udel.edu/berg/2
# URL already exists: https://fashionhistory.fitnyc.edu/
# URL already exists: http://cx2ef4jw8j.search.serialssolutions.com/ejp/?libHash=CX2EF4JW8J#/search/?searchControl=title&searchType=alternate_title_begins&criteria=vogue&language=en-US&titleType=JOURNALS
# URL already exists: https://fashionandrace.org/database/browse/
# URL already exists: https://guides.lib.udel.edu/bloomsberg-fashion-business-cases/2
# URL already exists: https://guides.lib.udel.edu/wgsn/2
# URL already exists: http://blog.patternbank.com/category/inspiration/
# URL already exists: https://guides.lib.udel.edu/businesscoll/2
# URL already exists: https://guides.lib.udel.edu/bsp/2
# URL already exists: https://guides.lib.udel.edu/abi/2
# URL already exists: https://guides.lib.udel.edu/aone/2
# URL already exists: https://guides.lib.udel.edu/expanded/2
# URL already exists: https://guides.lib.udel.edu/nexisuni/2
# URL already exists: https://guides.lib.udel.edu/big/2
# URL already exists: https://ec.europa.eu/eurostat/web/main/data/database
# URL already exists: https://globalgoodspartners.org/
# URL already exists: https://apparelcoalition.org/the-higg-index/
# URL already exists: https://knowthechain.org/benchmark-downloads/scorecard-downloads/
# URL already exists: https://knowthechain.org/benchmark-downloads/scorecard-downloads/
# URL already exists: https://knowthechain.org/benchmark-downloads/scorecard-downloads/
# URL already exists: https://knowthechain.org/benchmark-downloads/scorecard-downloads/
# URL already exists: https://www.un.org/sustainabledevelopment/sustainable-development-goals/
# URL already exists: https://trustuscotton.org/
# URL already exists: https://www.epa.gov/greenerproducts/furniture
# URL already exists: https://geca.eco/product-finder/
# URL already exists: https://sustainablefurnishings.org/company-search
# URL already exists: https://furniturescorecard.nwf.org/wood-furniture-scorecard-2022/
# URL already exists: https://www.scsglobalservices.com/resources/all
# URL already exists: http://mts.sustainableproducts.com/SMaRT_Certified.html
# URL already exists: https://textileexchange.org/materials/
# URL already exists: https://pfmm.textileexchange.org/
# URL already exists: https://sustainablepackaging.org/resources/
# URL already exists: https://libguides.hb.se/c.php?g=676473&p=4818943
# URL already exists: https://proxy.library.kent.edu/login?url=http://search.ebscohost.com/login.aspx?authtype=ip,shib&profile=bsi
# URL already exists: https://proxy.library.kent.edu/login?url=https://global.factiva.com/en/sess/login.asp?XSID=S000sVk3GVkZHmnNdmnMTYnODQsN92p5DByWcNGOTNHYdNZUUFBQUFBQUFBQUFBQUFBQUFBQUFBQUFBQUFBQUFBQUFBQUEA
# URL already exists: https://proxy.library.kent.edu/login?url=https://my.ibisworld.com/
# URL already exists: https://proxy.library.kent.edu/login?url=https://go.gale.com/ps/i.do?p=GVRL&sw=w&u=kent82803&v=2.1&it=aboutSeries&id=0IAD&sid=GVRL
# URL already exists: https://proxy.library.kent.edu/login?url=http://academic.mintel.com
# URL already exists: https://myaccount.nytimes.com/verification/edupass
# URL already exists: https://proxy.library.kent.edu/login?url=http://www.nexisuni.com
# URL already exists: https://proxy.library.kent.edu/login?url=http://www.wwd.com/wwd-publications?&page=1
# URL already exists: https://www.aafaglobal.org/AAFA/Solutions_Pages/Tools_Research.aspx
# URL already exists: https://proxy.library.kent.edu/login?url=https://www.ama.org/
# URL already exists: https://www.aatcc.org/read/
# URL already exists: https://www.apparelsearch.com/
# URL already exists: https://fashionunited.com/markets/1/products
# URL already exists: https://rn.ftc.gov/Account/LoginWelcome
# URL already exists: https://www.fibre2fashion.com/
# URL already exists: https://shop.notjustalabel.com/
# URL already exists: https://www.usfashionindustry.com/
# URL already exists: https://ecoquery.ecoinvent.org/3.9.1/cutoff/search
# (http://ecoinvent.lca-data.com/)
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_PC020__custom_3026894/default/table?lang=en
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_PC030__custom_6118521/bookmark/table?lang=en&bookmarkId=0c90dea9-f1b1-46f6-94d4-991847523013
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_PC034__custom_4515332/bookmark/table?lang=en&bookmarkId=1f55e371-e0c7-4539-8acb-9e5698dca3a0
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_PC032__custom_4515379/bookmark/table?lang=en&bookmarkId=279ce800-c8a6-49cc-8cb3-78429cae55d9
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_PC031__custom_4515440/bookmark/table?lang=en&bookmarkId=792ec8bf-1883-475d-b9c5-ce85f7f68ae8
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_PC035__custom_6033664/bookmark/table?lang=en&bookmarkId=7c2cd07e-9c2a-409e-a826-bb6b47be882b
# URL already exists: https://ec.europa.eu/eurostat/databrowser/bookmark/ba41257a-a19c-495c-aafd-93b118598930?lang=en
# URL already exists: https://ec.europa.eu/eurostat/databrowser/bookmark/ecd7424a-bd4e-4c3f-b241-0d679b79026d?lang=en
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_WM011__custom_4515615/bookmark/table?lang=en&bookmarkId=1d0ad10f-5330-4c0a-b281-91768911abbe
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_WM010__custom_4515669/bookmark/table?lang=en&bookmarkId=6036958f-2f55-4a93-8cb7-5413f84ffbdb
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_WM020__custom_4515741/bookmark/table?lang=en&bookmarkId=beba8fd6-b451-4432-9a42-608dc7c87efe
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/cei_wm060/default/table?lang=en
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_SRM030__custom_4515826/bookmark/table?lang=en&bookmarkId=89bebabe-6d9c-4a7e-b969-6a98c780f754
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_SRM010__custom_3026831/default/table?lang=en
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_SRM020__custom_3024535/bookmark/table?lang=en&bookmarkId=7cc4bc60-30c4-49b3-8680-cdd538f5c235
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_SRM020__custom_3024549/bookmark/table?lang=en&bookmarkId=0d71963c-72ff-4fcd-b819-004307d5c461
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_SRM020__custom_3024550/bookmark/table?lang=en&bookmarkId=5faedda1-8efa-4bcb-9a15-ae27974c2f5d
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_CIE012__custom_6093049/bookmark/table?lang=en&bookmarkId=8e16764e-c14a-4abb-b11c-2a1bd43e7eb1
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_CIE011__custom_6101297/bookmark/table?lang=en&bookmarkId=2c809d6c-cb60-464a-b404-dabcae6a01d2
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_CIE012__custom_6101336/bookmark/table?lang=en&bookmarkId=03be6bf1-c5fa-4b7b-bbfc-9a6b2a4e71b8
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_CIE012__custom_6101336/bookmark/table?lang=en&bookmarkId=03be6bf1-c5fa-4b7b-bbfc-9a6b2a4e71b8
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_GSR010__custom_6101390/bookmark/table?lang=en&bookmarkId=ff57a0ad-b588-4e13-9a9b-957ac8b98ba7
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_GSR011__custom_6101420/bookmark/table?lang=en&bookmarkId=7945fd21-1b20-4cd2-8ade-bbf7c7f4c47d
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_GSR030__custom_6101450/bookmark/table?lang=en&bookmarkId=926a3858-c1f2-40cf-9ffb-0f5fa0f3fa2e
# URL already exists: https://ec.europa.eu/eurostat/databrowser/view/CEI_GSR020__custom_6107682/bookmark/table?lang=en&bookmarkId=ba66ef16-a5d7-412e-b98b-8f6d5ec12c16
# URL already exists: https://ghgprotocol.org/life-cycle-databases
# URL already exists: https://www.cger.nies.go.jp/publications/report/d031/eng/datafile/index.htm
# URL already exists: https://www.athenasmi.org/our-software-data/lca-databases/
# URL already exists: https://www.auslci.com.au/index.php/Datasets
# URL already exists: https://www.forestresearch.gov.uk/tools-and-resources/fthr/biomass-energy-resources/reference-biomass/documents-downloads/beat/
# URL already exists: https://bregroup.com/products/impact/the-impact-database/
# URL already exists: https://uwaterloo.ca/canadian-raw-materials-database/life-cycle-inventory-databasesbases-donnees-linventaire
# URL already exists: http://www.ccalc.org.uk/ccalc2.php
# URL already exists: http://cpmdatabase.cpm.chalmers.se/Scripts/AdvGeneral.asp
# URL already exists: http://codde.fr/en/our-software/eime-en/eime-presentation
# URL already exists: https://weee-lci.ecosystem.eco/
# URL already exists: https://blonksustainability.nl/tools-and-databases/agri-footprint
# URL already exists: https://eplca.jrc.ec.europa.eu/LCDN/contactListILCD.xhtml
# URL already exists: https://esu-services.ch/data/public-lci-reports/
# URL already exists: https://fal.com/projects.html
# URL already exists: https://www.epa.gov/sciencematters/researchers-develop-regional-lifecycle-assessment-tool-electricity-use
# URL already exists: https://www.epa.gov/smm/smm-prioritization-tools-index
# URL already exists: https://napcor.com/sustainability/life-cycle-analysis/
# URL already exists: https://greet.anl.gov/greet/setup2022/greet.application
# URL already exists: https://www.biocycle.net/food-waste-recycling-environmental-and-economic-assessment/
# URL already exists: https://www.mdpi.com/2071-1050/12/13/5459
# URL already exists: www.ieaghg.org/index.php?/20091223127/co2-emissions-database.html
# URL already exists: https://www.nrel.gov/lci/
# URL already exists: https://nexus.openlca.org/search
# URL already exists: https://catalog.data.gov/dataset/supply-chain-greenhouse-gas-emission-factors-v1-2-by-naics-6
# URL already exists: https://www.nature.com/articles/s41597-021-00974-z#Sec3
# URL already exists: https://www.foodpackagingforum.org/fccmigex
# URL already exists: http://www.fabricmarketing.com/#search
# URL already exists: https://www.matweb.com/search/search.aspx
# URL already exists: https://www.ulprospector.com/en/na
# URL already exists: https://materialsproject.org/materials
# URL already exists: https://data.mendeley.com/datasets/9b4kkwf5g3/1
# URL already exists: https://www.matto.design/en/home/
# URL already exists: https://journey.designpossibility.com/7-material-libraries-for-your-next-sustainable-design-project-6d515294fef9
# URL already exists: https://materiom.org/search
# URL already exists: https://www.madec.polimi.it/
# URL already exists: https://www.materialdriven.com/
# URL already exists: https://matmatch.com/
# URL already exists: https://ec.europa.eu/eurostat/web/prodcom
# URL already exists: http://www.socialhotspot.org/
# URL already exists: https://psilca.net/
# URL already exists: https://www.nature.com/articles/s41597-020-0573-9
# URL already exists: https://www.globallcadataaccess.org/
# URL already exists: https://www.epa.gov/chemical-research/chemical-and-products-database-cpdat
# URL already exists: https://cosmetics.specialchem.com/formulations
# URL already exists: https://www.personalcaremagazine.com/formulations
# URL already exists: https://doc.agribalyse.fr/documentation-en/
# URL already exists: https://www.mintel.com/products/gnpd/
# URL already exists: https://rspo.org/
# URL already exists: https://pubchem.ncbi.nlm.nih.gov/
# URL already exists: https://www.iucnredlist.org/
# URL already exists: https://trade.cites.org/
# URL already exists: https://www.gs1.org/services/gdsn
# URL already exists: https://cleanclothes.org/campaigns/the-accord/brand-tracker
# URL already exists: https://www.cbp.gov/newsroom/stats/trade/uyghur-forced-labor-prevention-act-statistics
# URL already exists: https://gfems.org/flare/
# URL already exists: https://data.gov.in/catalog/company-master-data
# URL already exists: https://www.zaubacorp.com/company-list
# URL already exists: https://panjiva.com/search
# URL already exists: https://www.importgenius.com/pricing
# URL already exists: https://docs.ewaybillgst.gov.in/
# URL already exists: https://opensupplyhub.org/
# URL already exists: https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: https://clb.org.hk/en Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: https://appareldata.org/entries/better-buying/ Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: https://portal.betterwork.org/transparency/compliance Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: https://www.business-humanrights.org/en/companies/ Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: https://fashionchecker.org/ Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: https://www.csrhub.com/ Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: https://www.fairlabor.org/accountability/assessments/agriculture-assessments/?report_type=agriculture-assessment Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: https://www.fairlabor.org/accountability/assessments/assessments-manufacturing/?report_type=workplace-monitoring Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: https://mappedinbangladesh.org/ Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: https://www.reprisk.com/solutions#datasets-and-metrics Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: https://violationtracker.goodjobsfirst.org/?advanced_mode=true Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: https://wageindicator.org/ Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: https://bangladeshaccord.org/ Found via ICAR Directory https://appareldata.org/directory/?theme=forced-labor&displayRows=10&step=1&
# URL already exists: https://transparentem.org/
# URL already exists: https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: found on https://fashionunited.com/i/sustainability-certification-organizations-in-fashion
# URL already exists: https://www.blog.industrialecology.uni-freiburg.de/index.php/2023/11/16/major-update-of-the-industrial-ecology-data-commons/
# URL already exists: https://issuu.com/fashionrevolution/docs/fashion_transparency_index_2023_pages
# URL already exists: https://wad.jrc.ec.europa.eu/geoportal
# URL already exists: https://resourcewatch.org/data/explore?section=Discover&selectedCollection=&zoom=3&lat=0&lng=0&pitch=0&bearing=0&basemap=dark&labels=light&aoi=&page=1&sort=most-viewed&sortDirection=-1
# URL already exists: http://lcdn.thinkstep.com/Node/
# URL already exists: http://ecoinvent.lca-data.com/
# URL already exists: http://lcdn.blonkconsultants.nl/
# URL already exists: http://lcdn-cepe.org/
# URL already exists: Sustainable Development Report 2023 (sdgindex.org)
# URL already exists: https://unstats.un.org/unsd/unsystem/Documents-Sept2018/BG-Item6-MAPS.pdf
# URL already exists: https://datatopics.worldbank.org/sdgatlas/
# URL already exists: https://www.usgs.gov/mission-areas/water-resources/maps
# URL already exists: https://www.pewtrusts.org/en/trend/archive/spring-2019/a-map-of-the-future-of-water
# URL already exists: https://waterscarcityatlas.org/
# URL already exists: https://worldwater.io/
# URL already exists: https://www.wri.org/data/water-stress-country
# URL already exists: https://wad.jrc.ec.europa.eu/introduction
# URL already exists: https://ec.europa.eu/jrc/en/news/new-world-atlas-desertification-shows-unprecedented-pressure-planets-natural-resources
# URL already exists: https://earth.org/data_visualization/how-desertification-has-affected-these-9-countries-since-1984/
# URL already exists: https://www.globalforestwatch.org/map/
# URL already exists: https://gisgeography.com/global-forest-maps/
# URL already exists: https://www.geospatialworld.net/blogs/world-banks-interactive-map-shows-deforestation-severe/
# URL already exists: https://ourworldindata.org/deforestation
# URL already exists: https://gisgeography.com/climate-change-effects-maps/
# URL already exists: https://www.climate.gov/maps-data
# URL already exists: https://impactlab.org/map/
# URL already exists: https://waqi.info/
# URL already exists: https://aqicn.org/map/world/
# URL already exists: https://www.iqair.com/earth
# URL already exists: https://www.usgs.gov/faqs/how-can-i-find-depth-water-table-specific-location?qt-news_science_products=0
# URL already exists: https://groundwaterwatch.usgs.gov/default.asp
# URL already exists: https://www2.bgs.ac.uk/groundwater/datainfo/hydromaps/home.html
# URL already exists: https://www.americangeosciences.org/critical-issues/maps/interactive-map-groundwater-information-around-world
# URL already exists: https://www.usgs.gov/mission-areas/water-resources/science/saltwater-intrusion
# URL already exists: https://www.eea.europa.eu/data-and-maps/indicators/saltwater-intrusion/saltwater-intrusion
# URL already exists: https://www.sfwmd.gov/sites/default/files/documents/ws-58_swi_mapping_report_final.pdf
# URL already exists: https://biodiversitymapping.org/
# URL already exists: https://mol.org/
# URL already exists: https://atlas-for-the-end-of-the-world.com/world_maps/world_maps_biological_hotspots.html
# URL already exists: https://www.natureserve.org/map-biodiversity-importance
# URL already exists: https://storymaps.arcgis.com/collections/6730f10b64184200b171a57750890643?item=3
# URL already exists: https://www.arcgis.com/apps/webappviewer/index.html?id=6dee9bfbb7c0423cb06b7f74c026482f
# URL already exists: https://www.usgs.gov/programs/environmental-health-program/science/interactive-map-provides-long-term-look-changes-river
# URL already exists: https://www.wwf.org.uk/uk-rivers-map
# URL already exists: https://www.vox.com/2016/4/25/11503152/shipping-routes-map
# URL already exists: https://www.marinetraffic.com/en/ais/home/centerx:-12.0/centery:25.0/zoom:4
# URL already exists: https://transportgeography.org/wp-content/uploads/Map_Main-Maritime-Routes.pdf
# URL already exists: https://www.dailymail.co.uk/sciencetech/article-3745728/The-incredible-interactive-map-reveals-route-merchant-ship-ocean-2012.html
# URL already exists: https://planetarycomputer.microsoft.com/
# URL already exists: https://level.ecomedes.com
# URL already exists: https://stat.unido.org/
# URL already exists: https://stat.unido.org/content/dataset_description/indstat-2-2023%252c-isic-revision-3
# URL already exists: https://stats.oecd.org/index.aspx?queryid=69557
# URL already exists: https://gepir.gs1.org/index.php/search-by-gtin
# URL already exists: https://www.gs1us.org/tools/gs1-company-database-gepir
# URL already exists: see Smart Formulations methodology for context https://docs.google.com/document/d/1CSGP68h7m8im9HX09xv_ENdaQYG_mLbyxDgUa0EGkaE/edit
# URL already exists: see Smart Formulations methodology for context https://docs.google.com/document/d/1CSGP68h7m8im9HX09xv_ENdaQYG_mLbyxDgUa0EGkaE/edit
# URL already exists: see Smart Formulations methodology for context https://docs.google.com/document/d/1CSGP68h7m8im9HX09xv_ENdaQYG_mLbyxDgUa0EGkaE/edit
# URL already exists: see Smart Formulations methodology for context https://docs.google.com/document/d/1CSGP68h7m8im9HX09xv_ENdaQYG_mLbyxDgUa0EGkaE/edit
# URL already exists: see Smart Formulations methodology for context https://docs.google.com/document/d/1CSGP68h7m8im9HX09xv_ENdaQYG_mLbyxDgUa0EGkaE/edit
# URL already exists: see Smart Formulations methodology for context https://docs.google.com/document/d/1CSGP68h7m8im9HX09xv_ENdaQYG_mLbyxDgUa0EGkaE/edit
# URL already exists: https://www.aafaglobal.org/AAFA/Solutions_Pages/Commitment_to_Responsible_Recruitment
# URL already exists: https://www.aafaglobal.org/AAFA/Solutions_Pages/Restricted_Substance_List.aspx
# URL already exists: https://www.aafaglobal.org/AAFA/Directories/Made_in_USA_Directory.aspx?WebsiteKey=49c45f4d-69b3-4c66-823a-6d285960fed2
# URL already exists: https://climatetrace.org/data
# URL already exists: Company search http://123.49.32.36:7781/psp/nc_search (homepage https://roc.gov.bd/)
# URL already exists: https://www.whatsinproducts.com/types/type_detail/1/7318/standard/Ralph%20Lauren%20Candlelight%20RL2700/18-027-001
# URL already exists: https://epd-australasia.com/
# URL already exists: SaferProducts.gov
# URL already exists: https://data.cityofnewyork.us/Health/Metal-Content-of-Consumer-Products-Tested-by-the-N/da9u-wz3r
# URL already exists: https://fdc.nal.usda.gov/
# URL already exists: https://www.ars.usda.gov/northeast-area/beltsville-md-bhnrc/beltsville-human-nutrition-research-center/methods-and-application-of-food-composition-laboratory/mafcl-site-pages/database-resources/
# URL already exists: https://commodities.cmie.com/
# URL already exists: https://www.fao.org/infoods/infoods/tables-and-databases/en
# URL already exists: https://resourcetrade.earth/
# URL already exists: https://tka.nutridata.ee/et/?groups=&component=39&exclude=false&type=all&starts=true&query=
# URL already exists: https://tka.nutridata.ee/en/useful-links
# URL already exists: https://ciqual.anses.fr/
# URL already exists: https://ghgprotocol.org/Third-Party-Databases/Carnegie-Mellon
# URL already exists: https://ghgprotocol.org/Third-Party-Databases/BUWAL
# URL already exists: https://ghgprotocol.org/Third-Party-Databases/CPM-Chalmers

# %%
# Run the scrape_all_sources function to start scraping
scrape_all_sources()
# Out:
# Scraping data from https://www.bettershoes.org/home/material-selection
# Data scraped and stored for source ID 646b0493-b4d6-4dc0-a053-8e4bc2782d13
# Scraping data from https://hpp.arkema.com/en/materials-database/products
# Data scraped and stored for source ID b5c7c7b9-3e20-4d62-a1b1-4a7896ea2365
# Scraping data from https://quantis.com/who-we-guide/our-impact/sustainability-initiatives/waldb/
# Data scraped and stored for source ID b368e658-95e3-4db3-babf-6a6fb5bcabda
# Scraping data from https://envioes.com/en/product-sizes
# Failed to scrape https://envioes.com/en/product-sizes: 404 Client Error: Not Found for url: https://envioes.com/en/product-sizes
# Scraping data from https://www.shipbob.com/blog/dimensional-weight-explained/
# Failed to scrape https://www.shipbob.com/blog/dimensional-weight-explained/: 403 Client Error: Forbidden for url: https://www.shipbob.com/blog/dimensional-weight-explained/
# Scraping data from http://www.fedex.com/in/tools/dimweight.html
# Data scraped and stored for source ID 4a649817-3640-442e-a245-1721db4577a2
# Scraping data from https://www.biobasedconsultancy.com/en/database
# Data scraped and stored for source ID ec87442a-8c37-4898-a752-f61786491753
# Scraping data from https://textileexchange.org/find-certified-company/
# Data scraped and stored for source ID b62e7edc-fbe1-4f6e-b728-77b8578bb2fd
# Scraping data from https://apparelcoalition.org/higg-product-tools/
# Data scraped and stored for source ID 97e0d991-c675-4300-b564-591b5932960f
# Scraping data from https://libguides.hb.se/c.php?g=676473&p=4818943
# Data scraped and stored for source ID c4123ce6-4cdb-4c42-8dff-d84de8cf1136
# Scraping data from https://login.lib.costello.pub.hb.se/login?qurl=https%3a%2f%2fwww.materialconnexion.online%2fdatabase
# Data scraped and stored for source ID e3b3365b-2fac-4782-bef1-ba97284f739a
# Scraping data from https://www.stylepark.com/en/products/fabrics-textiles
# Failed to scrape https://www.stylepark.com/en/products/fabrics-textiles: 403 Client Error: Forbidden for url: https://www.stylepark.com/en/products/fabrics-textiles
# Scraping data from https://materialdistrict.com/material/
# Failed to scrape https://materialdistrict.com/material/: 403 Client Error: Forbidden for url: https://materialdistrict.com/material/
# Scraping data from https://ep.liu.se/databaser.aspx
# Data scraped and stored for source ID b716ba9f-abdb-4181-bd7c-6b2d5f632fb3
# Scraping data from https://subjects.library.manchester.ac.uk/textiles/databases/
# Failed to scrape https://subjects.library.manchester.ac.uk/textiles/databases/: 404 Client Error: Not Found for url: https://subjects.library.manchester.ac.uk/textiles/databases/
# Scraping data from https://libguides.library.kent.edu/c.php?g=278144&p=1853934
# Data scraped and stored for source ID 3fcc5557-a531-4cb9-a8d1-f2ab97663f19
# Scraping data from http://www.fabricmarketing.com/#search
# Data scraped and stored for source ID 7f5a1601-25c1-48fd-ac1f-9ef7e0c3013d
# Scraping data from https://elemental.green/10-trustworthy-green-product-databases-for-building-or-renovating-your-home/
# Failed to scrape https://elemental.green/10-trustworthy-green-product-databases-for-building-or-renovating-your-home/: 403 Client Error: Forbidden for url: https://elemental.green/10-trustworthy-green-product-databases-for-building-or-renovating-your-home/
# Scraping data from https://c2ccertified.org/certified-products
# Data scraped and stored for source ID 3442bf8f-0bf3-4053-a64c-d3a5f343afd4
# Scraping data from https://transparencycatalog.com/
# Failed to scrape https://transparencycatalog.com/: 403 Client Error: Forbidden for url: https://transparencycatalog.com/
# Scraping data from https://hpdrepository.hpd-collaborative.org/Pages/Results.aspx
# Data scraped and stored for source ID 2738ee76-0793-417c-8537-5fa474c734c0
# Scraping data from https://declare.living-future.org/
# Data scraped and stored for source ID eaf60571-5b92-4ac4-97af-806de715eb80
# Scraping data from https://portal.mindfulmaterials.com/
# Failed to scrape https://portal.mindfulmaterials.com/: 403 Client Error: Forbidden for url: https://portal.mindfulmaterials.com/
# Scraping data from https://spot.ul.com/main-app/products/catalog/
# Data scraped and stored for source ID fa283fd0-0018-478d-bc7e-4c15f6b1e566
# Scraping data from https://certified.greenseal.org/directory
# Data scraped and stored for source ID 392ce4e0-e37c-4690-8368-842393b5ed8d
# Scraping data from https://www.energystar.gov/products
# Data scraped and stored for source ID a34c942a-d3a3-483d-8aa3-d33b814ab7c9
# Scraping data from https://www.greenpointrated.com/
# Data scraped and stored for source ID 26ec6f69-8572-4b2d-bb66-9f2e98be92ca
# Scraping data from https://healthymaterialslab.org/material-collections/product-libraries/external-certification-libraries
# Data scraped and stored for source ID 1fbc4abd-3203-473c-b02f-e077f7242bf4
# Scraping data from https://www.resetbuild.com/
# Data scraped and stored for source ID 38657439-cec3-4fa6-9ebe-9a6871823fa6
# Scraping data from https://www.environdec.com/library
# Data scraped and stored for source ID dd54379d-5b10-4b50-8f6d-52b370bc064d
# Scraping data from https://level.bifma.org/
# Failed to scrape https://level.bifma.org/: 403 Client Error: Forbidden for url: https://level.bifma.org/
# Scraping data from http://www.decorativesurfaces.org/cpa-green/naf-nauf-ulef.html
# Failed to scrape http://www.decorativesurfaces.org/cpa-green/naf-nauf-ulef.html: 403 Client Error: Forbidden for url: http://www.decorativesurfaces.org/cpa-green/naf-nauf-ulef.html
# Scraping data from https://ww2.arb.ca.gov/sites/default/files/classic/toxics/compwood/naf_ulef/listofnaf_ulef.htm
# Failed to scrape https://ww2.arb.ca.gov/sites/default/files/classic/toxics/compwood/naf_ulef/listofnaf_ulef.htm: 404 Client Error: Not Found for url: https://ww2.arb.ca.gov/sites/default/files/classic/toxics/compwood/naf_ulef/listofnaf_ulef.htm
# Scraping data from https://buildingclean.ecomedes.com/
# Failed to scrape https://buildingclean.ecomedes.com/: 403 Client Error: Forbidden for url: https://buildingclean.ecomedes.com/
# Scraping data from https://www.oeko-tex.com/en/buying-guide
# Data scraped and stored for source ID 380e8a2b-36ae-4c9a-816a-6dfa0df531ff
# Scraping data from https://www.epa.gov/saferchoice/products
# Data scraped and stored for source ID e0bff4cd-1c3a-4723-9ec6-27423af27c24
# Scraping data from https://app.powerbi.com/view?r=eyJrIjoiMzAyMzVkNWMtNmJhOS00ZDg4LWIzMTItNzczMDkwODBiNjRmIiwidCI6ImIyNGM4YjA2LTUyMmMtNDZmZS05MDgwLTcwOTI2ZjhkZGRiMSIsImMiOjh9
# Data scraped and stored for source ID 7e075bc9-3fb1-4fc4-8859-e141eaf42f38
# Scraping data from http://www.sustainableminds.com/transparency-products
# Data scraped and stored for source ID 1fc056bf-1a0c-4cc2-801d-1e2e7b9e2e37
# Scraping data from https://origin.build/#/materials?p=P&locale=en
# Data scraped and stored for source ID 63135fd3-307f-4362-ae45-5a7429503353
# Scraping data from http://ecoscorecard.com/
# Data scraped and stored for source ID 131d14b4-c417-407b-ab7e-e16fcf489194
# Scraping data from https://www.designerpages.com/search/?
# Data scraped and stored for source ID 0e4c8899-3ea8-4985-a85d-027c85536795
# Scraping data from https://healthyurbanplaces.wixsite.com/materialspetal
# Data scraped and stored for source ID 9fa418a8-2154-453c-80c8-0fe71844c842
# Scraping data from https://living-future.org/wp-content/uploads/2016/11/Materials-List.pdf
# Failed to scrape https://living-future.org/wp-content/uploads/2016/11/Materials-List.pdf: 404 Client Error: Not Found for url: https://living-future.org/wp-content/uploads/2016/11/Materials-List.pdf
# Scraping data from https://s3.amazonaws.com/healthy-materials-lab/resources/Bullitt-Center-As-Built-Product-List-Jan-20141.pdf
# Failed to scrape https://s3.amazonaws.com/healthy-materials-lab/resources/Bullitt-Center-As-Built-Product-List-Jan-20141.pdf: 403 Client Error: Forbidden for url: https://s3.amazonaws.com/healthy-materials-lab/resources/Bullitt-Center-As-Built-Product-List-Jan-20141.pdf
# Scraping data from https://www.ewg.org/guides/cleaners/#.WrGPOJMbNE4
# Failed to scrape https://www.ewg.org/guides/cleaners/#.WrGPOJMbNE4: 403 Client Error: Forbidden for url: https://www.ewg.org/guides/cleaners/#.WrGPOJMbNE4
# Scraping data from https://www.svanen.se/en/
# Data scraped and stored for source ID 8f9dfb5a-7abc-42f7-9754-a8704914cbbb
# Scraping data from https://ceh.org/wp-content/uploads/Purchaser-Guide-August-2017-2.pdf
# Failed to scrape https://ceh.org/wp-content/uploads/Purchaser-Guide-August-2017-2.pdf: 404 Client Error: Not Found for url: https://ceh.org/wp-content/uploads/Purchaser-Guide-August-2017-2.pdf
# Scraping data from https://www.wood-database.com/wood-articles/restricted-and-endangered-wood-species/
# Data scraped and stored for source ID d90b64d8-65d7-4550-a5c6-80e8f0809bbc
# Scraping data from https://woodforgood.com/lifecycle-database/
# Data scraped and stored for source ID f50c6a6a-c561-4876-bfc9-4be92cf15399
# Scraping data from https://resourcefurniture.com/
# Data scraped and stored for source ID 3b895af3-0860-42d6-88b3-a08e78f50b60
# Scraping data from https://www.theconsumergoodsforum.com/
# Failed to scrape https://www.theconsumergoodsforum.com/: 403 Client Error: Forbidden for url: https://www.theconsumergoodsforum.com/
# Scraping data from https://www.iopp.org/i4a/pages/index.cfm?pageid=1
# Data scraped and stored for source ID f58196cf-bef2-4992-982c-76166b50687e
# Scraping data from https://www.iom3.org/group/packaging-group.html
# Data scraped and stored for source ID 34f30c26-a796-4710-9887-1042421f1a62
# Scraping data from https://sustainablepackaging.org/our-work/public-resources/
# Failed to scrape https://sustainablepackaging.org/our-work/public-resources/: 403 Client Error: Forbidden for url: https://sustainablepackaging.org/our-work/public-resources/
# Scraping data from https://incpen.org/library/factsheets/
# Failed to scrape https://incpen.org/library/factsheets/: ('Received response with content-encoding: gzip, but failed to decode it.', error('Error -3 while decompressing data: incorrect header check'))
# Scraping data from https://www.luxepack.com/
# Data scraped and stored for source ID bff61627-ddeb-4b07-95a5-594ca7b0fb08
# Scraping data from https://www.thepackagingconference.com/
# Data scraped and stored for source ID 27663b39-0bbc-4180-b93d-937556ba405c
# Scraping data from https://www.sustainability-in-packaging.com/home
# Data scraped and stored for source ID 2b7fe111-5110-40b8-8807-4b80f3025a27
# Scraping data from https://www.imengineeringwest.com/en/home.html
# Failed to scrape https://www.imengineeringwest.com/en/home.html: 403 Client Error: Forbidden for url: https://www.mdmwest.com/en/home.html
# Scraping data from https://www.packagingdigest.com/trends-issues/sustainability
# Failed to scrape https://www.packagingdigest.com/trends-issues/sustainability: 403 Client Error: Forbidden for url: https://www.packagingdigest.com/trends-issues/sustainability
# Scraping data from https://www.packagingstrategies.com/topics/2671-materials
# Data scraped and stored for source ID 78a7df46-e253-4591-a32a-1a626b4013fa
# Scraping data from https://www.packworld.com/downloads
# Data scraped and stored for source ID 08b06dfa-333c-4d39-8435-578bab2c38b5
# Scraping data from https://astrx.org/resources/
# Failed to scrape https://astrx.org/resources/: 403 Client Error: Forbidden for url: https://astrx.org/resources/
# Scraping data from https://earthshiftglobal.com/packagesmart
# Data scraped and stored for source ID 90d35cb5-7ead-4b6c-99bc-24ab6d8eeba4
# Scraping data from https://sphera.com/sustainable-packaging-calculator/
# Failed to scrape https://sphera.com/sustainable-packaging-calculator/: 403 Client Error: Forbidden for url: https://sphera.com/sustainable-packaging-calculator/
# Scraping data from https://www.billerud.com/managed-packaging/knowledge-center/case-studies/sustainable-materials-better-bottom-line2
# Data scraped and stored for source ID d391ce12-a257-46fe-b85b-f21e315d998c
# Scraping data from https://www.billerud.com/managed-packaging/knowledge-center/case-studies/the-outside-does-actually-matter
# Data scraped and stored for source ID 56a0eddb-73a5-411d-ba32-3535f502350e
# Scraping data from https://www.billerud.com/managed-packaging/knowledge-center/case-studies/experience-the-joy-of-improvement
# Data scraped and stored for source ID e8d930ee-1b01-487c-ba41-c3c1ba249a5f
# Scraping data from https://www.billerud.com/managed-packaging/knowledge-center/case-studies/on-the-move-with-quality-and-style
# Data scraped and stored for source ID 103d3c1b-1fd8-4b35-935a-999128658b9f
# Scraping data from https://www.billerud.com/managed-packaging/knowledge-center/case-studies/a-great-fit-for-every-shoe
# Data scraped and stored for source ID f3ad2e0e-0de3-4d5b-9ecf-50999b421347
# Scraping data from https://www.theconsumergoodsforum.com/wp-content/uploads/2017/11/Global-Protocol-on-Packaging.pdf
# Data scraped and stored for source ID 55172e5a-14c9-41d1-b8f3-849a0d79d707
# Scraping data from https://ilostat.ilo.org/data/
# Data scraped and stored for source ID f45e0bf6-f0b2-4647-8199-2087add3d120
# Scraping data from https://www.oecd.org/employment/labour-stats/onlineoecdemploymentdatabase.htm
# Data scraped and stored for source ID 65bd1795-10df-4c2d-951a-6991f10e9f3a
# Scraping data from https://data.unicef.org/topic/child-protection/child-labour/
# Failed to scrape https://data.unicef.org/topic/child-protection/child-labour/: 403 Client Error: Forbidden for url: https://data.unicef.org/topic/child-protection/child-labour/
# Scraping data from https://ourworldindata.org/child-labor
# Data scraped and stored for source ID 3dc486c4-2014-43cf-802b-8e7ee340fb13
# Scraping data from https://jww.org/uyghur-china-forced-labor-database/
# Failed to scrape https://jww.org/uyghur-china-forced-labor-database/: 406 Client Error: Not Acceptable for url: https://jww.org/uyghur-china-forced-labor-database/
# Scraping data from https://www.dol.gov/agencies/ilab/reports/child-labor/list-of-goods
# Data scraped and stored for source ID 0ddc192f-bbf7-4a43-892c-90db658f60d4
# Scraping data from https://resourcewatch.org/data/explore
# Data scraped and stored for source ID 2c537674-4b0f-4f2b-924b-d188d88198f8
# Scraping data from https://www.suslab.ch/_files/ugd/d5df01_641484631fd44be1ab23dbd6294c9256.pdf
# Data scraped and stored for source ID 64176fbc-553b-4043-9384-61fa49b3a75a
# Scraping data from http://lcdn.thinkstep.com/Node/
# Data scraped and stored for source ID e079b27b-4797-4d75-bc78-07ad425dbd56
# Scraping data from https://www.gs1.org/voc/PackagingMaterialTypeCode
# Failed to scrape https://www.gs1.org/voc/PackagingMaterialTypeCode: 403 Client Error: Forbidden for url: https://www.gs1.org/voc/PackagingMaterialTypeCode
# Scraping data from https://www.gs1.org/voc/PackagingRecyclingProcessTypeCode
# Failed to scrape https://www.gs1.org/voc/PackagingRecyclingProcessTypeCode: 403 Client Error: Forbidden for url: https://www.gs1.org/voc/PackagingRecyclingProcessTypeCode
# Scraping data from https://www.gs1.org/voc/PackagingFunctionCode
# Failed to scrape https://www.gs1.org/voc/PackagingFunctionCode: 403 Client Error: Forbidden for url: https://www.gs1.org/voc/PackagingFunctionCode
# Scraping data from https://www.gs1.org/voc/PackagingFeatureCode
# Failed to scrape https://www.gs1.org/voc/PackagingFeatureCode: 403 Client Error: Forbidden for url: https://www.gs1.org/voc/PackagingFeatureCode
# Scraping data from https://www.gs1.org/voc/PackagingShapeCode
# Failed to scrape https://www.gs1.org/voc/PackagingShapeCode: 403 Client Error: Forbidden for url: https://www.gs1.org/voc/PackagingShapeCode
# Scraping data from https://www.materials.zone/platform
# Data scraped and stored for source ID c39b0ea0-3719-4be8-abff-fc7e10358d19
# Scraping data from https://guides.lib.udel.edu/fashion/databases
# Data scraped and stored for source ID 89231b26-2b8e-40d3-ac19-da8d66b57888
# Scraping data from https://guides.lib.udel.edu/berg/2
# Data scraped and stored for source ID e9533e26-1a6a-472b-b984-724d5d75ab31
# Scraping data from https://fashionhistory.fitnyc.edu/
# Failed to scrape https://fashionhistory.fitnyc.edu/: 403 Client Error: Forbidden for url: https://fashionhistory.fitnyc.edu/
# Scraping data from http://cx2ef4jw8j.search.serialssolutions.com/ejp/?libHash=CX2EF4JW8J#/search/?searchControl=title&searchType=alternate_title_begins&criteria=vogue&language=en-US&titleType=JOURNALS
# Data scraped and stored for source ID 920410ae-4140-45c7-a56b-aeba796cd865
# Scraping data from https://fashionandrace.org/database/browse/
# Failed to scrape https://fashionandrace.org/database/browse/: 403 Client Error: Forbidden for url: https://fashionandrace.org/database/browse/
# Scraping data from https://guides.lib.udel.edu/bloomsberg-fashion-business-cases/2
# Data scraped and stored for source ID 41e0b4aa-bb77-4101-8be4-2c0d320c1074
# Scraping data from https://guides.lib.udel.edu/wgsn/2
# Data scraped and stored for source ID dee9fa84-69cd-49c4-bf87-420aa8de1207
# Scraping data from http://blog.patternbank.com/category/inspiration/
# Failed to scrape http://blog.patternbank.com/category/inspiration/: HTTPConnectionPool(host='blog.patternbank.com', port=80): Max retries exceeded with url: /category/inspiration/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000273218628B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Scraping data from https://guides.lib.udel.edu/businesscoll/2
